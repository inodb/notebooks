# %% [markdown]
# # Find Genes that are Copy Number Regulated using TCGA

# %%
import pandas as pd
import numpy as np
import scipy.stats
import glob

# %% [markdown]
# - Copy number data per gene

# %%
cn = pd.read_csv("copynumber.txt", sep="\t").set_index("Gene Symbol")

# %%
cn.head()
# Out:
#              Locus ID Cytoband  TCGA-A1-A0SB-01  TCGA-A1-A0SD-01  \
# Gene Symbol
# ACAP3          116983  1p36.33                0               -1
# AGRN           375790  1p36.33                0               -1
# ATAD3A          55210  1p36.33                0               -1
# ATAD3B          83858  1p36.33                0               -1
# ATAD3C         219293  1p36.33                0               -1
#
#              TCGA-A1-A0SE-01  TCGA-A1-A0SF-01  TCGA-A1-A0SG-01  \
# Gene Symbol
# ACAP3                      0                0                0
# AGRN                       0                0                0
# ATAD3A                     0                0                0
# ATAD3B                     0                0                0
# ATAD3C                     0                0                0
#
#              TCGA-A1-A0SH-01  TCGA-A1-A0SI-01  TCGA-A1-A0SJ-01  \
# Gene Symbol
# ACAP3                     -1                0                0
# AGRN                      -1                0                0
# ATAD3A                    -1                0                0
# ATAD3B                    -1                0                0
# ATAD3C                    -1                0                0
#
#                   ...         TCGA-EW-A1PB-01  TCGA-EW-A1PD-01  \
# Gene Symbol       ...
# ACAP3             ...                       0                0
# AGRN              ...                       0                0
# ATAD3A            ...                       0                0
# ATAD3B            ...                       0                0
# ATAD3C            ...                       0                0
#
#              TCGA-EW-A1PE-01  TCGA-EW-A1PF-01  TCGA-EW-A1PG-01  \
# Gene Symbol
# ACAP3                     -1               -1                0
# AGRN                      -1               -1                0
# ATAD3A                    -1               -1                0
# ATAD3B                    -1               -1                0
# ATAD3C                    -1               -1                0
#
#              TCGA-EW-A1PH-01  TCGA-EW-A2FS-01  TCGA-EW-A2FV-01  \
# Gene Symbol
# ACAP3                      0                0                0
# AGRN                       0                0                0
# ATAD3A                     0                0                0
# ATAD3B                     0                0                0
# ATAD3C                     0                0                0
#
#              TCGA-EW-A2FW-01  TCGA-GI-A2C8-01
# Gene Symbol
# ACAP3                     -1               -1
# AGRN                      -1               -1
# ATAD3A                    -1               -1
# ATAD3B                    -1               -1
# ATAD3C                    -1               -1
#
# [5 rows x 775 columns]

# %% [markdown]
# - expression data per gene

# %%
# get expression column to sample mapping
file_sample_map = {".".join(l.split("\t")[0].split(".")[:4]):l.split("\t")[1][:-13] for l in [r.strip() for r in open("FILE_SAMPLE_MAP.txt").readlines()][1:-1]}
# get gene locus to gene id mapping
locus_gene_id_map = {cn.ix[i,"Locus ID"]:i for i in cn.index}
locus_gene_id_map_func = lambda x: locus_gene_id_map.get(int(x.split("|")[1]), "NOT_IN_CN")
exp = pd.read_csv("expression.txt", sep="\t", converters={"gene_id": locus_gene_id_map_func}) \
    .rename(columns=file_sample_map).set_index("gene_id")

# %%
exp.head()
# Out:
#                   TCGA-B6-A0RG-01  TCGA-BH-A0DS-01  TCGA-BH-A0HK-11  \
# gene_id
# ?|100130426                0.0000           0.0000           0.0000
# ?|100133144|2of2           8.1811           5.4201           0.0000
# ?|100134869|2of2           6.0469           5.6217           3.3606
# ?|10357                  125.7651          49.7792          77.6219
# ?|10431                 1381.1291        1203.5526         695.2664
#
#                   TCGA-A2-A0D1-01  TCGA-BH-A0HW-01  TCGA-BH-A18U-11  \
# gene_id
# ?|100130426                0.0000           0.0000           0.0000
# ?|100133144|2of2           5.3773          10.3750           9.4575
# ?|100134869|2of2          20.9912          17.8179           4.6934
# ?|10357                  118.4932         110.0920          96.6604
# ?|10431                 1575.9859         777.5317         744.8113
#
#                   TCGA-A8-A08B-01  TCGA-A8-A07W-01  TCGA-B6-A0WT-01  \
# gene_id
# ?|100130426                0.0000           0.0000           0.0000
# ?|100133144|2of2          17.0230           9.9595          14.1703
# ?|100134869|2of2           5.0618           9.1078          11.9329
# ?|10357                   85.6890         146.6338          87.6321
# ?|10431                 1369.2580         895.5271         796.1467
#
#                   TCGA-AO-A12F-01       ...         TCGA-BH-A0E0-01  \
# gene_id                                 ...
# ?|100130426                0.0000       ...                  0.0000
# ?|100133144|2of2          10.5997       ...                  4.8507
# ?|100134869|2of2          14.2407       ...                 10.9933
# ?|10357                  147.1816       ...                 92.8397
# ?|10431                 2210.4636       ...               1728.2145
#
#                   TCGA-AO-A0JI-01  TCGA-A7-A13F-01  TCGA-A7-A0D9-11  \
# gene_id
# ?|100130426                0.0000           0.0000           0.0000
# ?|100133144|2of2           3.3396           0.0000           3.0550
# ?|100134869|2of2           7.2624           1.2048           0.0000
# ?|10357                   35.7554          77.4137          87.5764
# ?|10431                  965.1647         986.7470         770.3666
#
#                   TCGA-BH-A1ES-06  TCGA-BH-A0H5-11  TCGA-BH-A0BM-11  \
# gene_id
# ?|100130426                0.0000           0.0000           0.0000
# ?|100133144|2of2          15.0504          27.5073          10.3417
# ?|100134869|2of2          16.2671           6.9755           2.7277
# ?|10357                  153.2109          73.2821          85.5242
# ?|10431                  713.1030         550.0623         693.9409
#
#                   TCGA-BH-A0BT-01  TCGA-BH-A0DK-01  TCGA-AR-A1AH-01
# gene_id
# ?|100130426                0.0000           0.0000           0.0000
# ?|100133144|2of2           5.0619           1.3501          18.1003
# ?|100134869|2of2           4.9085           6.3006           7.7237
# ?|10357                  163.9050         116.9442         126.1252
# ?|10431                 1409.6551        1318.1818        2325.5034
#
# [5 rows x 520 columns]

# %% [markdown]
# Divide into copy number variation groups of
#
#    - no gain vs gain ``[-2,1,0]`` and ``[1,2]``
#    - loss vs no loss ``[-2,-1]`` and ``[0,1,2]``

# %%
def split_groups(t, threshold):
    """Divide row t in two based on copy number. Perform Mann-Witney U test. Return p value"""
    # check if expression data exists
    if t.name in exp.index:
        x = exp.ix[t.name, t[t < threshold].index].dropna()
        y = exp.ix[t.name, t[t >= threshold].index].dropna()
    else:
        return 1

    # check group size
    if min(len(x), len(y)) < 0.10 * max(len(x), len(y)):
        return 1
    # scipy doc says Mann-Witney U should have more than 20 samples in x and y
    elif min(len(x), len(y)) <= 20:
        return 1
    # check if there is actual expression
    elif x.sum() + y.sum() < 1:
        return 1
    # check that the direction of the expression is similar to CNV
    elif x.mean() >= y.mean():
        return 1
    else:
        # perform Mann-Witney U-test, also call Wilcoxon rank sum test (not to be confused with Wilcoxon signed rank test)
        return scipy.stats.mannwhitneyu(x, y)[1]

# %%
# Corner cases split_groups for testing
# non-existent gene expression data
e1 = cn.ix["FAM138F|641702|1of3", :]
# all expression is 0
e2 = cn.ix["PRAMEF3", :]

# %%
cn_loss_pvalue = cn.ix[:,2:len(cn.columns)].apply(split_groups, axis=1, args=(0,))

# %%
cn_gain_pvalue = cn.ix[:,2:len(cn.columns)].apply(split_groups, axis=1, args=(1,))

# %%
from statsmodels.sandbox.stats.multicomp import multipletests

# %% [markdown]
# - Adjust p value with Benjamini Hochberg

# %%
cn_loss_adj_pvalue = multipletests(cn_loss_pvalue, alpha=0.05, method="fdr_bh")
cn_gain_adj_pvalue = multipletests(cn_gain_pvalue, alpha=0.05, method="fdr_bh")

# %%
cn_loss_adj_pvalue
# Out:
# (array([ True,  True,  True, ...,  True, False,  True], dtype=bool),
#  array([  6.77406963e-11,   6.68963879e-09,   1.46730243e-09, ...,
#           5.21453385e-28,   1.00000000e+00,   1.36284928e-16]),
#  2.4863417654730213e-06,
#  2.423654871546292e-06)

# %%
cn[cn_loss_adj_pvalue[0]].head()
# Out:
#              Locus ID Cytoband  TCGA-A1-A0SB-01  TCGA-A1-A0SD-01  \
# Gene Symbol
# ACAP3          116983  1p36.33                0               -1
# AGRN           375790  1p36.33                0               -1
# ATAD3A          55210  1p36.33                0               -1
# ATAD3B          83858  1p36.33                0               -1
# ATAD3C         219293  1p36.33                0               -1
#
#              TCGA-A1-A0SE-01  TCGA-A1-A0SF-01  TCGA-A1-A0SG-01  \
# Gene Symbol
# ACAP3                      0                0                0
# AGRN                       0                0                0
# ATAD3A                     0                0                0
# ATAD3B                     0                0                0
# ATAD3C                     0                0                0
#
#              TCGA-A1-A0SH-01  TCGA-A1-A0SI-01  TCGA-A1-A0SJ-01  \
# Gene Symbol
# ACAP3                     -1                0                0
# AGRN                      -1                0                0
# ATAD3A                    -1                0                0
# ATAD3B                    -1                0                0
# ATAD3C                    -1                0                0
#
#                   ...         TCGA-EW-A1PB-01  TCGA-EW-A1PD-01  \
# Gene Symbol       ...
# ACAP3             ...                       0                0
# AGRN              ...                       0                0
# ATAD3A            ...                       0                0
# ATAD3B            ...                       0                0
# ATAD3C            ...                       0                0
#
#              TCGA-EW-A1PE-01  TCGA-EW-A1PF-01  TCGA-EW-A1PG-01  \
# Gene Symbol
# ACAP3                     -1               -1                0
# AGRN                      -1               -1                0
# ATAD3A                    -1               -1                0
# ATAD3B                    -1               -1                0
# ATAD3C                    -1               -1                0
#
#              TCGA-EW-A1PH-01  TCGA-EW-A2FS-01  TCGA-EW-A2FV-01  \
# Gene Symbol
# ACAP3                      0                0                0
# AGRN                       0                0                0
# ATAD3A                     0                0                0
# ATAD3B                     0                0                0
# ATAD3C                     0                0                0
#
#              TCGA-EW-A2FW-01  TCGA-GI-A2C8-01
# Gene Symbol
# ACAP3                     -1               -1
# AGRN                      -1               -1
# ATAD3A                    -1               -1
# ATAD3B                    -1               -1
# ATAD3C                    -1               -1
#
# [5 rows x 775 columns]

# %% [markdown]
# - Copy number variation without expression data

# %%
len([i for i in cn.index if i not in exp.index])
# Out:
# 1013

# %% [markdown]
# - Expression data without copy number variation

# %%
len([i for i in exp.index if i not in cn.index])
# Out:
# 914

# %% [markdown]
# - Expression data and copy number variation

# %%
len([i for i in exp.index if i in cn.index])
# Out:
# 19617

# %% [markdown]
# - Number of genes that are copy number regulated with adj p value < 0.05

# %%
cn_loss_adj_pvalue[0].sum()
# Out:
# 9358

# %%
cn_gain_adj_pvalue[0].sum()
# Out:
# 7204

# %%
(cn_gain_adj_pvalue[0] | cn_loss_adj_pvalue[0]).sum()
# Out:
# 13121

# %%
(cn_gain_adj_pvalue[0] & cn_loss_adj_pvalue[0]).sum()
# Out:
# 3441

# %%
len(cn.index)
# Out:
# 20630

# %%
len(exp.index)
# Out:
# 20531

# %%
(cn_loss_pvalue < 0.05).sum()
# Out:
# 9812

# %% [markdown]
# - write copy number regulated genes to txt

# %%
with open("loss_copy_number_regulated_genes.txt", "w") as fh:
    for i in cn[cn_loss_adj_pvalue[0]].index:
        fh.write("{}\n".format(i))

# %%
with open("gain_copy_number_regulated_genes.txt", "w") as fh:
    for i in cn[cn_gain_adj_pvalue[0]].index:
        fh.write("{}\n".format(i))

# %% [markdown]
# **SUMMARY**
# These are a lot of  genes (more than half). So we might want to do things more stringently.
#
# - [ x ] Direction of expression should correspond to CNV
# - [ x ] Same analysis per subtype e.g. LumA, LumB, Basal, Her2, (Normal?)
# - [   ] More stringent Multiple Comparison Test than Benjamini-Hochberg
# - [   ] http://genenames.org, http://www.genenames.org/cgi-bin/symbol_checker
# - [ x ] Include only tumor samples (01-09), not normals (>10) (https://wiki.nci.nih.gov/display/TCGA/TCGA+Barcode).

# %% [markdown]
# ## Per subtype

# %%
tcga = pd.read_csv("MyTCGA_table.txt", sep="\t")

# %%
tcga.groupby("PAM50").Sample.count()
# Out:
# PAM50
# Basal      81
# Her2       53
# LumA      209
# LumB      112
# Normal      8
# Name: Sample, dtype: int64

# %%
subtypes = {g[0]:g[1].Sample.apply(lambda x: x[:-1]) for g in tcga.groupby("PAM50")}

# %%
# %%time
# create data frame to hold p values per subtype
cn_reg = pd.DataFrame(index=cn.index)
for k in subtypes:
    # loss
    cn_reg[k + "_loss_pvalue"] = cn.ix[:,subtypes[k]].apply(split_groups, axis=1, args=(0,))
    bh_res = multipletests(cn_reg[k + "_loss_pvalue"], alpha=0.05, method="fdr_bh")
    cn_reg[k + "_loss_adj_bhr_pvalue"] = bh_res[1]
    cn_reg[k + "_loss_adj_bhr_pvalue_bool"] = bh_res[0]
    # gain
    cn_reg[k + "_gain_pvalue"] = cn.ix[:,subtypes[k]].apply(split_groups, axis=1, args=(1,))
    bh_res = multipletests(cn_reg[k + "_gain_pvalue"], alpha=0.05, method="fdr_bh")
    cn_reg[k + "_gain_adj_bhr_pvalue"] = bh_res[1]
    cn_reg[k + "_gain_adj_bhr_pvalue_bool"] = bh_res[0]
    # amplification
    cn_reg[k + "_amp_pvalue"] = cn.ix[:,subtypes[k]].apply(split_groups, axis=1, args=(2,))
    bh_res = multipletests(cn_reg[k + "_amp_pvalue"], alpha=0.05, method="fdr_bh")
    cn_reg[k + "_amp_adj_bhr_pvalue"] = bh_res[1]
    cn_reg[k + "_amp_adj_bhr_pvalue_bool"] = bh_res[0]
# Out:
# CPU times: user 11min 19s, sys: 1.37 s, total: 11min 20s
# Wall time: 11min 22s

# %%
cn_reg.head()
# Out:
#              Basal_loss_pvalue  Basal_loss_adj_bhr_pvalue  \
# Gene Symbol
# ACAP3                        1                          1
# AGRN                         1                          1
# ATAD3A                       1                          1
# ATAD3B                       1                          1
# ATAD3C                       1                          1
#
#             Basal_loss_adj_bhr_pvalue_bool  Basal_gain_pvalue  \
# Gene Symbol
# ACAP3                                False                  1
# AGRN                                 False                  1
# ATAD3A                               False                  1
# ATAD3B                               False                  1
# ATAD3C                               False                  1
#
#              Basal_gain_adj_bhr_pvalue Basal_gain_adj_bhr_pvalue_bool  \
# Gene Symbol
# ACAP3                                1                          False
# AGRN                                 1                          False
# ATAD3A                               1                          False
# ATAD3B                               1                          False
# ATAD3C                               1                          False
#
#              Basal_amp_pvalue  Basal_amp_adj_bhr_pvalue  \
# Gene Symbol
# ACAP3                       1                         1
# AGRN                        1                         1
# ATAD3A                      1                         1
# ATAD3B                      1                         1
# ATAD3C                      1                         1
#
#             Basal_amp_adj_bhr_pvalue_bool  Her2_loss_pvalue  \
# Gene Symbol
# ACAP3                               False                 1
# AGRN                                False                 1
# ATAD3A                              False                 1
# ATAD3B                              False                 1
# ATAD3C                              False                 1
#
#                          ...               LumB_amp_adj_bhr_pvalue_bool  \
# Gene Symbol              ...
# ACAP3                    ...                                      False
# AGRN                     ...                                      False
# ATAD3A                   ...                                      False
# ATAD3B                   ...                                      False
# ATAD3C                   ...                                      False
#
#             LumA_loss_pvalue  LumA_loss_adj_bhr_pvalue  \
# Gene Symbol
# ACAP3               0.000000                  0.000002
# AGRN                0.000084                  0.000507
# ATAD3A              0.000086                  0.000518
# ATAD3B              0.000026                  0.000167
# ATAD3C              0.000348                  0.001909
#
#              LumA_loss_adj_bhr_pvalue_bool LumA_gain_pvalue  \
# Gene Symbol
# ACAP3                                 True                1
# AGRN                                  True                1
# ATAD3A                                True                1
# ATAD3B                                True                1
# ATAD3C                                True                1
#
#              LumA_gain_adj_bhr_pvalue  LumA_gain_adj_bhr_pvalue_bool  \
# Gene Symbol
# ACAP3                               1                          False
# AGRN                                1                          False
# ATAD3A                              1                          False
# ATAD3B                              1                          False
# ATAD3C                              1                          False
#
#             LumA_amp_pvalue  LumA_amp_adj_bhr_pvalue  \
# Gene Symbol
# ACAP3                     1                        1
# AGRN                      1                        1
# ATAD3A                    1                        1
# ATAD3B                    1                        1
# ATAD3C                    1                        1
#
#              LumA_amp_adj_bhr_pvalue_bool
# Gene Symbol
# ACAP3                               False
# AGRN                                False
# ATAD3A                              False
# ATAD3B                              False
# ATAD3C                              False
#
# [5 rows x 45 columns]

# %%
for k in subtypes:
    v = """
    Stats for {}
    Number of samples: {}
    Number of genes copy number regulated with adj p < 0.05
    GAIN: {}
    LOSS: {}
    AMP: {}
    UNION: {}
    INTERSECT: {}
    """.format(k,
               len(subtypes[k]),
               (cn_reg[k + "_gain_adj_bhr_pvalue_bool"]).sum(),
               (cn_reg[k + "_loss_adj_bhr_pvalue_bool"]).sum(),
               (cn_reg[k + "_amp_adj_bhr_pvalue_bool"]).sum(),
               (cn_reg[k + "_gain_adj_bhr_pvalue_bool"] | cn_reg[k + "_loss_adj_bhr_pvalue_bool"] | cn_reg[k + "_amp_adj_bhr_pvalue_bool"]).sum(),
               (cn_reg[k + "_gain_adj_bhr_pvalue_bool"] & cn_reg[k + "_loss_adj_bhr_pvalue_bool"] & cn_reg[k + "_amp_adj_bhr_pvalue_bool"]).sum(),
               )
    print v
# Out:
#     Stats for Basal
#     Number of samples: 81
#     Number of genes copy number regulated with adj p < 0.05
#     GAIN: 1746
#     LOSS: 2408
#     AMP: 0
#     UNION: 4154
#     INTERSECT: 0
#
#
#     Stats for Her2
#     Number of samples: 53
#     Number of genes copy number regulated with adj p < 0.05
#     GAIN: 508
#     LOSS: 601
#     AMP: 14
#     UNION: 1115
#     INTERSECT: 0
#
#
#     Stats for Normal
#     Number of samples: 8
#     Number of genes copy number regulated with adj p < 0.05
#     GAIN: 0
#     LOSS: 0
#     AMP: 0
#     UNION: 0
#     INTERSECT: 0
#
#
#     Stats for LumB
#     Number of samples: 112
#     Number of genes copy number regulated with adj p < 0.05
#     GAIN: 2716
#     LOSS: 4585
#     AMP: 11
#     UNION: 7030
#     INTERSECT: 0
#
#
#     Stats for LumA
#     Number of samples: 209
#     Number of genes copy number regulated with adj p < 0.05
#     GAIN: 4060
#     LOSS: 4787
#     AMP: 32
#     UNION: 8391
#     INTERSECT: 16

# %%
all_inter = pd.Series([True,]*len(cn_reg))
all_union = pd.Series([False,]*len(cn_reg))

for g in ("gain", "loss", "amp"):
    for k in subtypes:
        all_inter = np.bitwise_and(all_inter, cn_reg["{}_{}_adj_bhr_pvalue_bool".format(k, g)])
        all_union = np.bitwise_or(all_union, cn_reg["{}_{}_adj_bhr_pvalue_bool".format(k, g)])
v = """
All subtypes
Number of genes copy number regulated with adj p < 0.05
UNION: {}
INTERSECT: {}
""".format(all_union.sum(),
           all_inter.sum())
print v
# Out:
# All subtypes
# Number of genes copy number regulated with adj p < 0.05
# UNION: 10334
# INTERSECT: 0

# %% [markdown]
# This number is different from the initial 13K when not subtyping, prolly because of the way the adjusted p values have been computed. Should think about whether to include all subtypes when doing the Benjamini Hochberg procedure or per subtype.

# %% [markdown]
# ## Endometrial Cancer Spearman

# %% [markdown]
# Perform same analysis using Spearman correlation > 0.4 for CNV vs RNA expression.

# %%
freeze = pd.read_csv("data/UCEC_Final_Data_Freeze.txt", sep="\t")

# %%
freeze.head()
# Out:
#   PATIENT_BARCODE    SAMPLE_BARCODE               ALIQUOT_BARCODE  \
# 0    TCGA-A5-A0G1  TCGA-A5-A0G1-01A  TCGA-A5-A0G1-01A-01D-YYYY-23
# 1    TCGA-A5-A0G1  TCGA-A5-A0G1-01A  TCGA-A5-A0G1-01A-01D-YYYY-23
# 2    TCGA-A5-A0G1  TCGA-A5-A0G1-01A  TCGA-A5-A0G1-01A-01D-YYYY-23
# 3    TCGA-A5-A0G1  TCGA-A5-A0G1-01A  TCGA-A5-A0G1-01A-01D-YYYY-23
# 4    TCGA-A5-A0G1  TCGA-A5-A0G1-01A  TCGA-A5-A0G1-01A-11D-A120-01
#
#                            ALIQUOT_UUID                   DATATYPE  \
# 0  b6259957-a7f3-4f40-8327-e6a274bc6dc2      Complete_Clinical_Set
# 1  b6259957-a7f3-4f40-8327-e6a274bc6dc2  Fragment_Analysis_Results
# 2  b6259957-a7f3-4f40-8327-e6a274bc6dc2  Fragment_Analysis_Results
# 3  b6259957-a7f3-4f40-8327-e6a274bc6dc2  Fragment_Analysis_Results
# 4  2bf8abaf-8c88-4905-bbd6-9a16e80b2c18      Complete_Clinical_Set
#
#   PLATFORM_NAME                                  FILE_LOCATION_URL DATA_LEVEL  \
# 0           bio  /tcgafiles/ftp_auth/distro_ftpusers/anonymous/...          1
# 1    microsat_i  /tcgafiles/ftp_auth/distro_ftpusers/tcga4yeo/t...          1
# 2    microsat_i  /tcgafiles/ftp_auth/distro_ftpusers/tcga4yeo/t...          1
# 3    microsat_i  /tcgafiles/ftp_auth/distro_ftpusers/tcga4yeo/t...          1
# 4           bio  /tcgafiles/ftp_auth/distro_ftpusers/anonymous/...          1
#
#                                         ARCHIVE_NAME BATCH_NUMBER  \
# 0   nationwidechildrens.org_UCEC.bio.Level_1.92.25.0           92
# 1  nationwidechildrens.org_UCEC.microsat_i.Level_...           92
# 2  nationwidechildrens.org_UCEC.microsat_i.Level_...           92
# 3  nationwidechildrens.org_UCEC.microsat_i.Level_...           92
# 4   nationwidechildrens.org_UCEC.bio.Level_1.92.25.0           92
#
#                    DATE_ADDED
# 0  2012-08-03_17:21:09.684000
# 1  2012-10-01_15:38:30.647000
# 2  2012-10-01_15:38:30.647000
# 3  2012-10-01_15:38:30.647000
# 4  2012-08-03_17:21:09.684000

# %%
freeze.ARCHIVE_NAME.head()
# Out:
# 0     nationwidechildrens.org_UCEC.bio.Level_1.92.25.0
# 1    nationwidechildrens.org_UCEC.microsat_i.Level_...
# 2    nationwidechildrens.org_UCEC.microsat_i.Level_...
# 3    nationwidechildrens.org_UCEC.microsat_i.Level_...
# 4     nationwidechildrens.org_UCEC.bio.Level_1.92.25.0
# Name: ARCHIVE_NAME, dtype: object

# %%
freeze.FILE_LOCATION_URL[freeze.FILE_LOCATION_URL.str.contains("nocnv_hg19.seg.txt")].apply(lambda x: "/".join(["data", "copynumber"] + x.split("/")[-2:]))
# Out:
# 8       data/copynumber/broad.mit.edu_UCEC.Genome_Wide...
# 377     data/copynumber/broad.mit.edu_UCEC.Genome_Wide...
# 400     data/copynumber/broad.mit.edu_UCEC.Genome_Wide...
# 773     data/copynumber/broad.mit.edu_UCEC.Genome_Wide...
# 1173    data/copynumber/broad.mit.edu_UCEC.Genome_Wide...
# Name: FILE_LOCATION_URL, dtype: object

# %%
cnv = pd.read_csv("data/copynumber/broad.mit.edu_UCEC.Genome_Wide_SNP_6.Level_3.92.2002.0/CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712.nocnv_hg19.seg.txt", sep="\t")

# %%
cnv.head()
# Out:
#                                              Sample Chromosome      Start  \
# 0  CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712          1    3218610
# 1  CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712          2     484222
# 2  CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712          2  174540877
# 3  CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712          2  174540880
# 4  CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712          3    2212571
#
#          End  Num_Probes  Segment_Mean
# 0  247813706      129040        0.0017
# 1  174540876       92612        0.0073
# 2  174540879           2       -1.6545
# 3  242476062       38576        0.0077
# 4  197538677      106286        0.0023

# %%
refflat = pd.read_csv("data/refFlat_hg19.txt", sep="\t", names=[
    "name",
    "chrom",
    "strand",
    "txStart",
    "txEnd",
    "cdsStart",
    "cdsEnd",
    "exonCount",
    "exonStarts",
    "exonEnds"])

# %%
refflat.head()
# Out:
#               name          chrom strand    txStart      txEnd   cdsStart  \
# TRIM10   NM_052828  chr6_cox_hap2      -    1631860    1640846    1633601
# BHLHE23  NM_080606          chr20      -   61637330   61638387   61637400
# CRYBA2   NM_057094           chr2      -  219854911  219858127  219854973
# IFI6     NM_022873           chr1      -   27992571   27998724   27992891
# IFI6     NM_022872           chr1      -   27992571   27998724   27992891
#
#             cdsEnd  exonCount  \
# TRIM10     1640770          8
# BHLHE23   61638126          1
# CRYBA2   219857898          5
# IFI6      27995825          5
# IFI6      27995825          5
#
#                                                 exonStarts  \
# TRIM10   1631860,1634224,1635640,1636852,1637282,163831...
# BHLHE23                                          61637330,
# CRYBA2   219854911,219855573,219856823,219857737,219858...
# IFI6         27992571,27994736,27994968,27995731,27998633,
# IFI6         27992571,27994736,27994968,27995743,27998633,
#
#                                                   exonEnds
# TRIM10   1633685,1634400,1635673,1636968,1637305,163854...
# BHLHE23                                          61638387,
# CRYBA2   219855121,219855716,219856965,219857902,219858...
# IFI6         27992986,27994886,27995046,27995857,27998724,
# IFI6         27992986,27994886,27995046,27995857,27998724,

# %%
t = cnv.ix[3, :]

# %%
len(refflat[(refflat.txStart >= t.Start) & (refflat.txEnd <= t.End)])
# Out:
# 2869

# %%
t.Chromosome
# Out:
# '2'

# %%
(cnv.Chromosome == 1).sum()
# Out:
# 0

# %% [markdown]
# Filter hap chromosomes and keep only one entry per gene (there are varying exonCounts but we are not interested in that).

# %%
refflat_f = refflat[~refflat.chrom.str.contains("hap")].groupby(refflat[~refflat.chrom.str.contains("hap")].index).head(1)

# %%
def get_cna_seg_mean_per_sample(row, cnv):
    return cnv[(cnv.Chromosome == str(row.chrom)[3:]) & (cnv.Start <= row.txStart) & (cnv.End >= row.txEnd)] \
        .groupby("Sample")["Segment_Mean"].median()

# %%
# %%time
for i, f in enumerate(glob.glob("data/copynumber/*/*nocnv_hg19.seg.txt")[:100]):
    df = refflat_f.head(100).apply(get_cna_seg_mean_per_sample, axis=1, args=(cnv, ))
    if i == 0:
        cna_seg_mean_per_sample = df
    else:
        cna_seg_mean_per_sample = pd.concat([cna_seg_mean_per_sample, df], axis=1)
# Out:
# CPU times: user 23.8 s, sys: 77.9 ms, total: 23.9 s
# Wall time: 23.9 s

# %%
cna_seg_mean_per_sample.head()
# Out:
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#                                ...                         \
# BHLHE23                        ...
# CRYBA2                         ...
# IFI6                           ...
# LRRC75B                        ...
# ASNSD1                         ...
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
# [5 rows x 100 columns]

# %%
# %%time
for i, f in enumerate(glob.glob("data/unc*IlluminaHiSeq*/*.rsem.genes.normalized_results")):
    df = pd.read_csv(f, sep="\t").set_index("gene_id").rename(columns={"normalized_count":f.split("/")[-1]})
    if i == 0:
        exp = df
    else:
        exp = pd.concat([exp, df], axis=1)
# Out:
# CPU times: user 13.7 s, sys: 12 s, total: 25.7 s
# Wall time: 26.3 s

# %%
exp.head()
# Out:
#              unc.edu.00186124-cecf-4580-9dca-cef7c09f741c.1635304.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            23.9929
# ?|100134869                                             9.8752
# ?|10357                                               502.1658
# ?|10431                                              1535.6506
#
#              unc.edu.02302c44-fe54-4b39-9bef-c56db229c2ac.1605364.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            32.0780
# ?|100134869                                            71.4479
# ?|10357                                               369.0098
# ?|10431                                               879.2198
#
#              unc.edu.02528092-3a7a-4ddf-8801-e47a48fdeafe.1611097.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            36.7797
# ?|100134869                                            22.5424
# ?|10357                                               652.4294
# ?|10431                                              1949.1525
#
#              unc.edu.03141105-bc66-4e89-ad97-c54fcf189468.1628166.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                           104.7419
# ?|100134869                                           154.8451
# ?|10357                                               417.5147
# ?|10431                                              1004.4248
#
#              unc.edu.06745c8c-5e2b-4131-93a5-9023c32665ac.1620077.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            18.9089
# ?|100134869                                            23.3731
# ?|10357                                               407.8841
# ?|10431                                              2480.8747
#
#              unc.edu.06c39fc6-9167-4913-bf84-4fde036869a2.1608043.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            43.2986
# ?|100134869                                            22.2581
# ?|10357                                               322.3829
# ?|10431                                              1377.7315
#
#              unc.edu.07508c27-8f79-414e-af9d-e78240df5c48.1627970.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            59.1699
# ?|100134869                                           107.6812
# ?|10357                                               279.5626
# ?|10431                                               987.8244
#
#              unc.edu.0824e6ac-f3f0-4b71-81a3-7ee671a256eb.1625588.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            12.7565
# ?|100134869                                             4.3461
# ?|10357                                               356.1066
# ?|10431                                              1284.7082
#
#              unc.edu.08890bb3-7ad1-41c2-8774-b10bf86ee047.1623958.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            77.0010
# ?|100134869                                            93.3982
# ?|10357                                               653.7585
# ?|10431                                              1605.6475
#
#              unc.edu.093be209-e5ac-4129-83b2-5f79f6a5c15f.1617158.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            50.1601
# ?|100134869                                            77.0641
# ?|10357                                               539.5996
# ?|10431                                              1112.9893
#
#                                                     ...                                          \
# gene_id                                             ...
# ?|100130426                                         ...
# ?|100133144                                         ...
# ?|100134869                                         ...
# ?|10357                                             ...
# ?|10431                                             ...
#
#              unc.edu.f501c084-03d5-48ad-b365-085773a7bd2d.1622313.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            23.2359
# ?|100134869                                            32.3197
# ?|10357                                              1087.3684
# ?|10431                                              1974.6589
#
#              unc.edu.f73e7e5b-239b-4ac9-861e-c8f42e68188e.1632101.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            24.0401
# ?|100134869                                            22.7603
# ?|10357                                               369.8949
# ?|10431                                              1892.0726
#
#              unc.edu.f9533750-9b2f-44a2-8b4e-941fe0c53acb.1611094.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            70.1425
# ?|100134869                                            27.2447
# ?|10357                                               389.7625
# ?|10431                                              1931.1164
#
#              unc.edu.fb1c341a-34f7-482c-a954-de07652990b1.1647605.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            11.1782
# ?|100134869                                            28.0054
# ?|10357                                               312.6313
# ?|10431                                              1641.3605
#
#              unc.edu.fb355c45-282b-4eff-8d06-074d9acf1ea5.1624291.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            41.6000
# ?|100134869                                            28.1436
# ?|10357                                               444.6564
# ?|10431                                              1531.2821
#
#              unc.edu.fb8cfa19-3dfb-4ad5-a64e-7f51837e56cf.1633759.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            31.7634
# ?|100134869                                            22.3869
# ?|10357                                               840.6270
# ?|10431                                              2054.8628
#
#              unc.edu.fcb43e1a-3b34-4ff1-8d3e-849fbf901877.1621558.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            14.5365
# ?|100134869                                            86.8811
# ?|10357                                               288.7677
# ?|10431                                              1233.3697
#
#              unc.edu.fcf451be-340a-4479-86ed-d6757d680386.1632766.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            49.9058
# ?|100134869                                            37.0052
# ?|10357                                               335.7068
# ?|10431                                              1074.3455
#
#              unc.edu.fd13e02a-4bfb-4aaa-bbf7-488660106a31.1621127.rsem.genes.normalized_results  \
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                             5.9444
# ?|100134869                                            25.6951
# ?|10357                                               871.3710
# ?|10431                                              1386.3854
#
#              unc.edu.fffc5da3-ed33-4f8d-982e-e75b2d707c4b.1616004.rsem.genes.normalized_results
# gene_id
# ?|100130426                                             0.0000
# ?|100133144                                            43.8223
# ?|100134869                                            89.0220
# ?|10357                                               699.4458
# ?|10431                                              1263.2437
#
# [5 rows x 338 columns]

# %% [markdown]
# remove whatever has ?

# %%
# drop gene_id containing ? and change geneid to match cnv
a = pd.DataFrame(exp.index)
exp.index = a.gene_id.apply(lambda x: x.split("|")[0])
a.index = exp.index
exp = exp[~a.gene_id.str.contains("\?")]

# %%
pd.Index([freeze.FILE_LOCATION_URL.str.contains(c) for c in exp.columns])

# %%
freeze[freeze.FILE_LOCATION_URL.str.contains(exp.columns[0])].SAMPLE_BARCODE
# Out:
# 16344    TCGA-AP-A05O-01A
# Name: SAMPLE_BARCODE, dtype: object

# %%
cna_vs_exp = pd.DataFrame(index=cna_seg_mean_per_sample.index)
cna_vs_exp = cna_seg_mean_per_sample.apply(lambda x: scipy.stats.spearmanr(x, exp.ix[x.name, :]), axis=1)
cna_vs_exp = pd.DataFrame({"corr":cna_vs_exp.apply(lambda x: x[0]),"p2tailed":cna_vs_exp.apply(lambda x: x[1])})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-92e8d44cc33f> in <module>()
#       1 cna_vs_exp = pd.DataFrame(index=cna_seg_mean_per_sample.index)
# ----> 2 cna_vs_exp = cna_seg_mean_per_sample.apply(lambda x: scipy.stats.spearmanr(x, exp.ix[x.name, :]), axis=1)
#       3 cna_vs_exp = pd.DataFrame({"corr":cna_vs_exp.apply(lambda x: x[0]),"p2tailed":cna_vs_exp.apply(lambda x: x[1])})
#
# /Users/debruiji/anaconda/envs/pyenv-27/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    3594                     if reduce is None:
#    3595                         reduce = True
# -> 3596                     return self._apply_standard(f, axis, reduce=reduce)
#    3597             else:
#    3598                 return self._apply_broadcast(f, axis)
#
# /Users/debruiji/anaconda/envs/pyenv-27/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    3684             try:
#    3685                 for i, v in enumerate(series_gen):
# -> 3686                     results[i] = func(v)
#    3687                     keys.append(v.name)
#    3688             except Exception as e:
#
# <ipython-input-180-92e8d44cc33f> in <lambda>(x)
#       1 cna_vs_exp = pd.DataFrame(index=cna_seg_mean_per_sample.index)
# ----> 2 cna_vs_exp = cna_seg_mean_per_sample.apply(lambda x: scipy.stats.spearmanr(x, exp.ix[x.name, :]), axis=1)
#       3 cna_vs_exp = pd.DataFrame({"corr":cna_vs_exp.apply(lambda x: x[0]),"p2tailed":cna_vs_exp.apply(lambda x: x[1])})
#
# /Users/debruiji/anaconda/envs/pyenv-27/lib/python2.7/site-packages/scipy/stats/stats.pyc in spearmanr(a, b, axis)
#    2743         br = np.apply_along_axis(rankdata,axisout,b)
#    2744     n = a.shape[axisout]
# -> 2745     rs = np.corrcoef(ar,br,rowvar=axisout)
#    2746
#    2747     olderr = np.seterr(divide='ignore')  # rs can have elements equal to 1
#
# /Users/debruiji/anaconda/envs/pyenv-27/lib/python2.7/site-packages/numpy/lib/function_base.pyc in corrcoef(x, y, rowvar, bias, ddof)
#    1949
#    1950     """
# -> 1951     c = cov(x, y, rowvar, bias, ddof)
#    1952     try:
#    1953         d = diag(c)
#
# /Users/debruiji/anaconda/envs/pyenv-27/lib/python2.7/site-packages/numpy/lib/function_base.pyc in cov(m, y, rowvar, bias, ddof)
#    1893     if y is not None:
#    1894         y = array(y, copy=False, ndmin=2, dtype=dtype)
# -> 1895         X = concatenate((X, y), axis)
#    1896
#    1897     X -= X.mean(axis=1-axis, keepdims=True)
#
# ValueError: ('all the input array dimensions except for the concatenation axis must match exactly', u'occurred at index BHLHE23')

# %%
a = pd.DataFrame(exp.index)

# %%
a[a.gene_id.str.contains("BHL")]
# Out:
#              gene_id
# 1503  BHLHA15|168620
# 1504    BHLHB9|80823
# 1505   BHLHE22|27319
# 1506  BHLHE23|128408
# 1507    BHLHE40|8553
# 1508   BHLHE41|79365

# %%
cna_seg_mean_per_sample.head().apply(spearmanr_missing_values, axis=1)
# Out:
# BHLHE23
# CRYBA2
# IFI6
# LRRC75B
# ASNSD1
# BHLHE23    (0, 1)
# CRYBA2     (0, 1)
# IFI6       (0, 1)
# LRRC75B    (0, 1)
# ASNSD1     (0, 1)
# dtype: object

# %%
b = pd.DataFrame(cna_seg_mean_per_sample.index, columns=["gene"])

# %%
b[b.gene.str.contains("\?")]
# Out:
# Empty DataFrame
# Columns: [gene]
# Index: []

# %%
print len(glob.glob("data/copynumber/*/*nocnv_hg19.seg.txt"))
# Out:
# 737

# %%
cna_seg_mean_per_sample.head()
# Out:
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712  \
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077
#
#          CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712
# BHLHE23                                            0.0026
# CRYBA2                                             0.0077
# IFI6                                               0.0017
# LRRC75B                                            0.0076
# ASNSD1                                             0.0077

# %%
refflat_f.apply(row=1)
# Out:
#                    name  chrom strand    txStart      txEnd   cdsStart  \
# BHLHE23       NM_080606  chr20      -   61637330   61638387   61637400
# CRYBA2        NM_057094   chr2      -  219854911  219858127  219854973
# IFI6          NM_022873   chr1      -   27992571   27998724   27992891
# LRRC75B       NM_207644  chr22      -   24981590   24989035   24981853
# ASNSD1        NM_019048   chr2      +  190526124  190535557  190530858
# COMMD6        NM_203495  chr13      -   76099354   76112008   76100724
# GPR151        NM_194251   chr5      -  145894416  145895676  145894416
# NSMF          NM_015537   chr9      -  140342022  140353786  140343845
# FBXL3         NM_012158  chr13      -   77579388   77601331   77581279
# NEUROG3       NM_020999  chr10      -   71331790   71333210   71332154
# FNDC8         NM_017559  chr17      +   33448630   33457751   33448712
# FIGF          NM_004469   chrX      -   15363712   15402535   15364254
# DFFB          NM_004402   chr1      +    3773830    3801993    3774167
# LRRC46        NM_033413  chr17      +   45908992   45915079   45909355
# SNX6          NM_021249  chr14      -   35030617   35099315   35032327
# FHL2          NM_201557   chr2      -  105977282  106055230  105977739
# ZDHHC22       NM_174976  chr14      -   77597612   77608134   77600025
# FOLR1         NM_016724  chr11      +   71900601   71907367   71903217
# ERO1LB        NM_019891   chr1      -  236378421  236445339  236381815
# ZNF790     NM_001242802  chr19      -   37309223   37328929   37309334
# MTRNR2L9   NM_001190706   chr6      +   62284007   62284534   62284232
# MGAT4D     NM_001277353   chr4      -  141364528  141419531  141364589
# NPIPA5     NM_001277325  chr16      -   15457480   15472151   15457515
# NPIPA2     NM_001277324  chr16      +   14805545   14820185   14805545
# SPTLC2        NM_004863  chr14      -   77972339   78083110   77978626
# AQP3          NM_004925   chr9      -   33441151   33447631   33442040
# CLTC          NM_004859  chr17      +   57697049   57774317   57697492
# TBC1D9        NM_015130   chr4      -  141541935  141677471  141543348
# HAT1          NM_003642   chr2      +  172778934  172848600  172779010
# PYCR2         NM_013328   chr1      -  226107576  226112040  226108154
# ...                 ...    ...    ...        ...        ...        ...
# TMEM170A   NM_001304997  chr16      -   75477141   75498314   75481455
# MED11      NM_001001683  chr17      +    4634702    4636905    4634784
# SLC5A7     NM_001305005   chr2      +  108602969  108630439  108604611
# STAM2         NM_005843   chr2      -  152973314  153032506  152977087
# KIAA1715   NM_001305008   chr2      -  176788619  176867073  176794694
# CREB5         NM_004904   chr7      +   28475233   28865511   28527810
# ZNF713        NM_182633   chr7      +   55954969   56009918   55980329
# ZNF479        NM_033273   chr7      -   57187325   57207571   57187546
# PMS2P7        NR_130940   chr7      +   72476602   72486904   72486904
# ZNF804B       NM_181646   chr7      +   88388681   88966371   88389290
# KHDRBS3       NM_006558   chr8      +  136469707  136659852  136470109
# CKS2          NM_001827   chr9      +   91926109   91931618   91926207
# VCX2          NM_016378   chrX      -    8137984    8139308    8138072
# SPRY3      NM_001304990   chrX      +  154842225  155012119  155003533
# ZNF747     NM_001305018  chr16      -   30541687   30546291   30543819
# DYNLRB2    NM_001305017  chr16      +   80574630   80584706   80574661
# PPP3R2        NM_147180   chr9      -  104353896  104357283  104356690
# DSC2          NM_004949  chr18      -   28645939   28682395   28648274
# DSG1          NM_001942  chr18      +   28898051   28939209   28898263
# TMEM59     NM_001305043   chr1      -   54492353   54519111   54497822
# ZNF33B        NR_130951  chr10      -   43069630   43134285   43134285
# NAT9       NM_001305077  chr17      -   72766667   72772564   72767862
# PTOV1      NM_001305108  chr19      +   50353991   50364001   50354137
# STK38      NM_001305102   chr6      -   36461659   36515293   36463560
# DUSP26     NM_001305116   chr8      -   33448847   33455315   33449530
# NMRAL1     NM_001305141  chr16      -    4511677    4524651    4511780
# PTENP1-AS     NR_103745   chr9      +   33677265   33688008   33688008
# RSPRY1     NM_001305182  chr16      +   57220195   57239183   57238570
# TMEFF2     NM_001305134   chr2      -  192813771  193059659  192815177
# ZFP90      NM_001305203  chr16      +   68573115   68601039   68573695
#
#               cdsEnd  exonCount  \
# BHLHE23     61638126          1
# CRYBA2     219857898          5
# IFI6        27995825          5
# LRRC75B     24989006          4
# ASNSD1     190535452          6
# COMMD6      76111941          4
# GPR151     145895676          1
# NSMF       140353554         15
# FBXL3       77595995          5
# NEUROG3     71332799          2
# FNDC8       33457453          4
# FIGF        15402068          7
# DFFB         3800305          7
# LRRC46      45914486          8
# SNX6        35074845         13
# FHL2       106002973          6
# ZDHHC22     77606081          3
# FOLR1       71907221          6
# ERO1LB     236445083         16
# ZNF790      37316521          5
# MTRNR2L9    62284307          1
# MGAT4D     141419376         11
# NPIPA5      15472151          8
# NPIPA2      14820150          8
# SPTLC2      78082922         12
# AQP3        33447528          6
# CLTC        57771213         32
# TBC1D9     141677199         21
# HAT1       172848266         11
# PYCR2      226111810          7
# ...              ...        ...
# TMEM170A    75498148          3
# MED11        4636482          3
# SLC5A7     108627317          9
# STAM2      153032156         14
# KIAA1715   176867018         13
# CREB5       28858896         11
# ZNF713      56007699          7
# ZNF479      57200031          5
# PMS2P7      72486904          6
# ZNF804B     88966346          4
# KHDRBS3    136659327          9
# CKS2        91931340          3
# VCX2         8138684          3
# SPRY3      155004400          3
# ZNF747      30546000          3
# DYNLRB2     80584455          4
# PPP3R2     104357212          1
# DSC2        28681934         17
# DSG1        28935309         15
# TMEM59      54518861          8
# ZNF33B      43134285          4
# NAT9        72771837          7
# PTOV1       50363576         13
# STK38       36507979         14
# DUSP26      33455033          3
# NMRAL1       4524133          6
# PTENP1-AS   33688008          4
# RSPRY1      57238924          2
# TMEFF2     193059250         10
# ZFP90       68598601          5
#
#                                                   exonStarts  \
# BHLHE23                                            61637330,
# CRYBA2     219854911,219855573,219856823,219857737,219858...
# IFI6           27992571,27994736,27994968,27995731,27998633,
# LRRC75B                 24981590,24984181,24985788,24988829,
# ASNSD1     190526124,190528626,190530101,190530766,190532...
# COMMD6                  76099354,76104249,76111799,76111899,
# GPR151                                            145894416,
# NSMF       140342022,140344050,140344374,140344627,140346...
# FBXL3          77579388,77589543,77592734,77595647,77600961,
# NEUROG3                                   71331790,71332965,
# FNDC8                   33448630,33454060,33456440,33457300,
# FIGF       15363712,15365285,15371189,15373271,15376124,1...
# DFFB       3773830,3775281,3782375,3784537,3786168,378903...
# LRRC46     45908992,45909465,45911790,45912718,45913031,4...
# SNX6       35030617,35036891,35037059,35044961,35050766,3...
# FHL2       105977282,105979741,105984026,105990015,106002...
# ZDHHC22                          77597612,77605555,77607945,
# FOLR1      71900601,71901619,71903209,71906314,71906655,7...
# ERO1LB     236378421,236384131,236385223,236388369,236389...
# ZNF790         37309223,37314186,37314568,37316512,37328573,
# MTRNR2L9                                           62284007,
# MGAT4D     141364528,141372563,141377742,141380665,141383...
# NPIPA5     15457480,15459285,15459430,15460509,15463568,1...
# NPIPA2     14805545,14809924,14813683,14813946,14817048,1...
# SPTLC2     77972339,77984380,77987788,78018438,78021642,7...
# AQP3       33441151,33442298,33442849,33443318,33443763,3...
# CLTC       57697049,57721636,57724758,57725600,57728563,5...
# TBC1D9     141541935,141545269,141545467,141548594,141549...
# HAT1       172778934,172782046,172803227,172809398,172821...
# PYCR2      226107576,226108907,226109251,226109557,226109...
# ...                                                      ...
# TMEM170A                         75477141,75485566,75498129,
# MED11                               4634702,4635070,4636344,
# SLC5A7     108602969,108604563,108608561,108609427,108614...
# STAM2      152973314,152980279,152982739,152988627,152989...
# KIAA1715   176788619,176802071,176803040,176804279,176812...
# CREB5      28475233,28527792,28534523,28547233,28609982,2...
# ZNF713     55954969,55973945,55979308,55980327,55990854,5...
# ZNF479         57187325,57193724,57194298,57199992,57207314,
# PMS2P7     72476602,72479964,72481989,72482242,72483620,7...
# ZNF804B                 88388681,88847468,88956657,88962676,
# KHDRBS3    136469707,136533479,136554896,136560996,136569...
# CKS2                             91926109,91930084,91931287,
# VCX2                                8137984,8138582,8139147,
# SPRY3                         154842225,154997623,155003427,
# ZNF747                           30541687,30545517,30545771,
# DYNLRB2                 80574630,80577172,80583380,80584411,
# PPP3R2                                            104353896,
# DSC2       28645939,28648264,28648859,28650691,28651570,2...
# DSG1       28898051,28906543,28906836,28908151,28909854,2...
# TMEM59     54492353,54502282,54506428,54507396,54509045,5...
# ZNF33B                  43069630,43090042,43127376,43133921,
# NAT9       72766667,72768098,72768356,72769034,72769714,7...
# PTOV1      50353991,50357662,50357908,50358087,50358226,5...
# STK38      36461659,36464487,36465556,36466139,36467649,3...
# DUSP26                           33448847,33451050,33454812,
# NMRAL1      4511677,4513660,4516153,4519227,4524093,4524410,
# PTENP1-AS               33677265,33678087,33680891,33687756,
# RSPRY1                                    57220195,57238415,
# TMEFF2     192813771,192818404,192820980,192862987,192863...
# ZFP90          68573115,68573660,68591900,68592375,68596946,
#
#                                                     exonEnds
# BHLHE23                                            61638387,
# CRYBA2     219855121,219855716,219856965,219857902,219858...
# IFI6           27992986,27994886,27995046,27995857,27998724,
# LRRC75B                 24982379,24984297,24985917,24989035,
# ASNSD1     190526336,190528680,190530177,190532322,190532...
# COMMD6                  76100775,76104402,76111811,76112008,
# GPR151                                            145895676,
# NSMF       140343943,140344126,140344477,140344707,140346...
# FBXL3          77581923,77589715,77592857,77595996,77601331,
# NEUROG3                                   71332800,71333210,
# FNDC8                   33448921,33454436,33456677,33457751,
# FIGF       15364381,15365481,15371290,15373420,15376315,1...
# DFFB       3774281,3775408,3782564,3784617,3786339,378913...
# LRRC46     45909365,45909571,45911899,45912765,45913141,4...
# SNX6       35032381,35036977,35037219,35045048,35050806,3...
# FHL2       105977891,105979928,105984196,105990190,106002...
# ZDHHC22                          77600291,77606095,77608134,
# FOLR1      71900803,71901685,71903385,71906503,71906791,7...
# ERO1LB     236381876,236384265,236385310,236388439,236389...
# ZNF790         37311016,37314282,37314692,37316594,37328929,
# MTRNR2L9                                           62284534,
# MGAT4D     141364598,141372671,141377873,141380780,141383...
# NPIPA5     15457926,15459321,15459491,15460617,15463713,1...
# NPIPA2     14805608,14810053,14813783,14814091,14817156,1...
# SPTLC2     77978746,77984510,77987924,78018565,78021862,7...
# AQP3       33442209,33442516,33442968,33443456,33443890,3...
# CLTC       57697534,57721844,57725027,57725762,57728677,5...
# TBC1D9     141544071,141545373,141545542,141548681,141549...
# HAT1       172779017,172782151,172803303,172809519,172822...
# PYCR2      226108320,226109071,226109344,226109779,226110...
# ...                                                      ...
# TMEM170A                         75481586,75485737,75498314,
# MED11                               4634869,4635201,4636905,
# SLC5A7     108603219,108604789,108608675,108609583,108614...
# STAM2      152977316,152980449,152982893,152988682,152989...
# KIAA1715   176794927,176802242,176803111,176804385,176812...
# CREB5      28475307,28527864,28534617,28547355,28610155,2...
# ZNF713     55955373,55974072,55979761,55980416,55990981,5...
# ZNF479         57188859,57193820,57194425,57200045,57207571,
# PMS2P7     72476697,72480104,72482076,72482355,72483806,7...
# ZNF804B                 88389398,88847609,88956788,88966371,
# KHDRBS3    136470197,136533598,136555013,136561143,136569...
# CKS2                             91926266,91930212,91931618,
# VCX2                                8138390,8138830,8139308,
# SPRY3                         154842308,154997798,155012119,
# ZNF747                           30544472,30545631,30546291,
# DYNLRB2                 80574751,80577248,80583548,80584706,
# PPP3R2                                            104357283,
# DSC2       28648178,28648310,28649117,28650816,28651807,2...
# DSG1       28898311,28906579,28906968,28908307,28909999,2...
# TMEM59     54497978,54502391,54506513,54507478,54509198,5...
# ZNF33B                  43070126,43090147,43127472,43134285,
# NAT9       72767997,72768193,72768416,72769178,72769824,7...
# PTOV1      50354212,50357800,50357991,50358145,50358334,5...
# STK38      36463691,36464582,36465652,36466263,36467767,3...
# DUSP26                           33449730,33451265,33455315,
# NMRAL1      4511960,4513851,4516403,4519466,4524167,4524651,
# PTENP1-AS               33677507,33678285,33681071,33688008,
# RSPRY1                                    57220697,57239183,
# TMEFF2     192815190,192818563,192821104,192863047,192863...
# ZFP90          68573382,68573728,68592027,68592471,68601039,
#
# [26270 rows x 10 columns]

# %%
# !ls data/copynumber/broad.mit.edu_UCEC.Genome_Wide_SNP_6.Level_3.92.2002.0/CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712.nocnv_hg19.seg.txt
# Out:
# data/copynumber/broad.mit.edu_UCEC.Genome_Wide_SNP_6.Level_3.92.2002.0/CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_A05_735712.nocnv_hg19.seg.txt

# %%
freeze.ARCHIVE_NAME[freeze.ARCHIVE_NAME.str.contains("unc.edu")]
# Out:
# 23          unc.edu_UCEC.IlluminaGA_RNASeq.Level_3.2.7.0
# 24          unc.edu_UCEC.IlluminaGA_RNASeq.Level_3.2.7.0
# 25          unc.edu_UCEC.IlluminaGA_RNASeq.Level_3.2.7.0
# 26     unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 27     unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 28     unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 29     unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 30     unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 31     unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 412        unc.edu_UCEC.AgilentG4502A_07_3.Level_1.1.0.0
# 413        unc.edu_UCEC.AgilentG4502A_07_3.Level_2.1.0.0
# 414        unc.edu_UCEC.AgilentG4502A_07_3.Level_3.1.0.0
# 419         unc.edu_UCEC.IlluminaGA_RNASeq.Level_3.2.7.0
# 420         unc.edu_UCEC.IlluminaGA_RNASeq.Level_3.2.7.0
# 421         unc.edu_UCEC.IlluminaGA_RNASeq.Level_3.2.7.0
# ...
# 88127    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88128    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88129    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88130    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88131    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88132    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88176         unc.edu_UCEC.IlluminaGA_RNASeq.Level_3.2.7.0
# 88177         unc.edu_UCEC.IlluminaGA_RNASeq.Level_3.2.7.0
# 88178         unc.edu_UCEC.IlluminaGA_RNASeq.Level_3.2.7.0
# 88179    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88180    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88181    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88182    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88183    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# 88184    unc.edu_UCEC.IlluminaHiSeq_RNASeqV2.Level_3.1.0.0
# Name: ARCHIVE_NAME, Length: 3204, dtype: object
